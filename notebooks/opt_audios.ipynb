# %%
import numpy as np
import librosa
from scipy.io.wavfile import read
import seaborn as sns

sr, aud = read("/depot/jgmakin/data/audio_data/sent_0.wav")


a = np.load('/depot/jgmakin/data/auditory_cortex/opt_inputs/layer_0_64_channels.npy',allow_pickle=True)
b = np.load('/depot/jgmakin/data/auditory_cortex/opt_inputs/layer_1_64_channels.npy',allow_pickle=True)

#  `print(a.shape, b.shape)

# %%
# librosa.griffinlim(a[0]).shape
# sr, aud = read("/depot/jgmakin/data/audio_data/sent_0.wav")

a = librosa.feature.melspectrogram(aud, sr=sr)
sns.heatmap(a)
# Out:
# /tmp/ipykernel_34267/603522948.py:4: FutureWarning: Pass y=[-0.00082397  0.00054932  0.         ...  0.00067139  0.00082397
#  -0.00082397] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   a = librosa.feature.melspectrogram(aud, sr=sr)
# <AxesSubplot:>
